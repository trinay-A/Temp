# %% [markdown]
# <a href="https://colab.research.google.com/github/trinay-A/Temp/blob/main/FINAL_LSTMGRUBILSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Bidirectional

# %%
# Load the data
data = pd.read_csv('/content/DataBTC2017.csv')
values = data['CBBTCUSD'].values

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_values = scaler.fit_transform(values.reshape(-1, 1))

# %%
# Split the data into train and test sets
train_size = int(len(scaled_values) * 0.8)
train_data, test_data = scaled_values[:train_size], scaled_values[train_size:]

# %%
# Function to create the dataset with lookback
def create_dataset(data, lookback):
    X, Y = [], []
    for i in range(len(data)-lookback):
        X.append(data[i:(i+lookback), 0])
        Y.append(data[i+lookback, 0])
    return np.array(X), np.array(Y)

lookback = 10

# %%
# Create the train and test datasets
train_X, train_y = create_dataset(train_data, lookback)
test_X, test_y = create_dataset(test_data, lookback)

# %%
# Reshape the input data to fit the LSTM and GRU models
train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

# %%
# Build the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(50, input_shape=(lookback, 1)))
lstm_model.add(Dense(1))
lstm_model.compile(loss='mean_squared_error', optimizer='adam')

# Build the GRU model
gru_model = Sequential()
gru_model.add(GRU(50, input_shape=(lookback, 1)))
gru_model.add(Dense(1))
gru_model.compile(loss='mean_squared_error', optimizer='adam')

# Build the Bidirectional LSTM model
bilstm_model = Sequential()
bilstm_model.add(Bidirectional(LSTM(50, input_shape=(lookback, 1))))
bilstm_model.add(Dense(1))
bilstm_model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Train the models
lstm_history = lstm_model.fit(train_X, train_y, epochs=300, batch_size=16, verbose=1)
# gru_history = gru_model.fit(train_X, train_y, epochs=300, batch_size=16, verbose=1)
# bilstm_history = bilstm_model.fit(train_X, train_y, epochs=300, batch_size=16, verbose=1)
# lstm_history = lstm_model.fit(train_X, train_y, epochs=300, batch_size=32, verbose=1)
gru_history = gru_model.fit(train_X, train_y, epochs=100, batch_size=16, verbose=1)
bilstm_history = bilstm_model.fit(train_X, train_y, epochs=300, batch_size=16, verbose=1)
# Out:
# Epoch 1/300
# 39/39 [==============================] - 2s 7ms/step - loss: 0.0228
# Epoch 2/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 3/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 4/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 5/300
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 6/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0023
# Epoch 7/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 8/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 9/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 10/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 11/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 12/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 13/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 14/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 15/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 16/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 17/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 18/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 19/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 20/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 21/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 22/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 23/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 24/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 25/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 26/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 27/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 28/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 29/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 30/300
# 39/39 [==============================] - 0s 8ms/step - loss: 9.7556e-04
# Epoch 31/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 32/300
# 39/39 [==============================] - 0s 8ms/step - loss: 9.3122e-04
# Epoch 33/300
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 34/300
# 39/39 [==============================] - 0s 7ms/step - loss: 9.7869e-04
# Epoch 35/300
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 36/300
# 39/39 [==============================] - 0s 8ms/step - loss: 8.9470e-04
# Epoch 37/300
# 39/39 [==============================] - 0s 7ms/step - loss: 9.1457e-04
# Epoch 38/300
# 39/39 [==============================] - 0s 8ms/step - loss: 9.1609e-04
# Epoch 39/300
# 39/39 [==============================] - 0s 8ms/step - loss: 9.6573e-04
# Epoch 40/300
# 39/39 [==============================] - 0s 7ms/step - loss: 8.4996e-04
# Epoch 41/300
# 39/39 [==============================] - 0s 7ms/step - loss: 9.1121e-04
# Epoch 42/300
# 39/39 [==============================] - 0s 8ms/step - loss: 8.4897e-04
# Epoch 43/300
# 39/39 [==============================] - 0s 7ms/step - loss: 8.1379e-04
# Epoch 44/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.7886e-04
# Epoch 45/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.0789e-04
# Epoch 46/300
# 39/39 [==============================] - 1s 22ms/step - loss: 8.8205e-04
# Epoch 47/300
# 39/39 [==============================] - 1s 19ms/step - loss: 8.2975e-04
# Epoch 48/300
# 39/39 [==============================] - 1s 24ms/step - loss: 9.2123e-04
# Epoch 49/300
# 39/39 [==============================] - 0s 11ms/step - loss: 8.2435e-04
# Epoch 50/300
# 39/39 [==============================] - 0s 9ms/step - loss: 8.2832e-04
# Epoch 51/300
# 39/39 [==============================] - 1s 15ms/step - loss: 8.1785e-04
# Epoch 52/300
# 39/39 [==============================] - 0s 8ms/step - loss: 7.8030e-04
# Epoch 53/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.2432e-04
# Epoch 54/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.4512e-04
# Epoch 55/300
# 39/39 [==============================] - 0s 8ms/step - loss: 7.5936e-04
# Epoch 56/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.4913e-04
# Epoch 57/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.0689e-04
# Epoch 58/300
# 39/39 [==============================] - 0s 8ms/step - loss: 7.2001e-04
# Epoch 59/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.0490e-04
# Epoch 60/300
# 39/39 [==============================] - 0s 8ms/step - loss: 7.6013e-04
# Epoch 61/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.0327e-04
# Epoch 62/300
# 39/39 [==============================] - 0s 8ms/step - loss: 7.0049e-04
# Epoch 63/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.8964e-04
# Epoch 64/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.9472e-04
# Epoch 65/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.6062e-04
# Epoch 66/300
# 39/39 [==============================] - 0s 8ms/step - loss: 7.0835e-04
# Epoch 67/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.7933e-04
# Epoch 68/300
# 39/39 [==============================] - 0s 7ms/step - loss: 7.5749e-04
# Epoch 69/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.3724e-04
# Epoch 70/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.5261e-04
# Epoch 71/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.7673e-04
# Epoch 72/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.8013e-04
# Epoch 73/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.7645e-04
# Epoch 74/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.7558e-04
# Epoch 75/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.5871e-04
# Epoch 76/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.4957e-04
# Epoch 77/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.4983e-04
# Epoch 78/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.0767e-04
# Epoch 79/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.4648e-04
# Epoch 80/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.4196e-04
# Epoch 81/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.0949e-04
# Epoch 82/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.6394e-04
# Epoch 83/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.6340e-04
# Epoch 84/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.8977e-04
# Epoch 85/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.1801e-04
# Epoch 86/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0763e-04
# Epoch 87/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.2075e-04
# Epoch 88/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0463e-04
# Epoch 89/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9767e-04
# Epoch 90/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8931e-04
# Epoch 91/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.2520e-04
# Epoch 92/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.3255e-04
# Epoch 93/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7574e-04
# Epoch 94/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.1111e-04
# Epoch 95/300
# 39/39 [==============================] - 1s 17ms/step - loss: 6.1539e-04
# Epoch 96/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6855e-04
# Epoch 97/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9135e-04
# Epoch 98/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9676e-04
# Epoch 99/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0224e-04
# Epoch 100/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.1193e-04
# Epoch 101/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.3849e-04
# Epoch 102/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0357e-04
# Epoch 103/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9634e-04
# Epoch 104/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7928e-04
# Epoch 105/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7581e-04
# Epoch 106/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.1132e-04
# Epoch 107/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7855e-04
# Epoch 108/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8764e-04
# Epoch 109/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9132e-04
# Epoch 110/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.1476e-04
# Epoch 111/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6756e-04
# Epoch 112/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.4200e-04
# Epoch 113/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7096e-04
# Epoch 114/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4722e-04
# Epoch 115/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.6702e-04
# Epoch 116/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.1585e-04
# Epoch 117/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9183e-04
# Epoch 118/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6134e-04
# Epoch 119/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6488e-04
# Epoch 120/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8586e-04
# Epoch 121/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.9225e-04
# Epoch 122/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.3977e-04
# Epoch 123/300
# 39/39 [==============================] - 1s 13ms/step - loss: 5.8272e-04
# Epoch 124/300
# 39/39 [==============================] - 1s 28ms/step - loss: 5.5702e-04
# Epoch 125/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9814e-04
# Epoch 126/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9795e-04
# Epoch 127/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0715e-04
# Epoch 128/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0302e-04
# Epoch 129/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7927e-04
# Epoch 130/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5681e-04
# Epoch 131/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6767e-04
# Epoch 132/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6234e-04
# Epoch 133/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5684e-04
# Epoch 134/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7685e-04
# Epoch 135/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.4897e-04
# Epoch 136/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6616e-04
# Epoch 137/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5525e-04
# Epoch 138/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7741e-04
# Epoch 139/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5542e-04
# Epoch 140/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7435e-04
# Epoch 141/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5496e-04
# Epoch 142/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8319e-04
# Epoch 143/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4522e-04
# Epoch 144/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5744e-04
# Epoch 145/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5684e-04
# Epoch 146/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7800e-04
# Epoch 147/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7511e-04
# Epoch 148/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8426e-04
# Epoch 149/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6416e-04
# Epoch 150/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6283e-04
# Epoch 151/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8992e-04
# Epoch 152/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5385e-04
# Epoch 153/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.4756e-04
# Epoch 154/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8454e-04
# Epoch 155/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5927e-04
# Epoch 156/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6049e-04
# Epoch 157/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.4502e-04
# Epoch 158/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7425e-04
# Epoch 159/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9884e-04
# Epoch 160/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4804e-04
# Epoch 161/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5099e-04
# Epoch 162/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.2260e-04
# Epoch 163/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7954e-04
# Epoch 164/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8444e-04
# Epoch 165/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5917e-04
# Epoch 166/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5862e-04
# Epoch 167/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6945e-04
# Epoch 168/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5570e-04
# Epoch 169/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6458e-04
# Epoch 170/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5445e-04
# Epoch 171/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6503e-04
# Epoch 172/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5495e-04
# Epoch 173/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5914e-04
# Epoch 174/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7989e-04
# Epoch 175/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7355e-04
# Epoch 176/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9214e-04
# Epoch 177/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5579e-04
# Epoch 178/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0309e-04
# Epoch 179/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6477e-04
# Epoch 180/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6316e-04
# Epoch 181/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8098e-04
# Epoch 182/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9067e-04
# Epoch 183/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6127e-04
# Epoch 184/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5097e-04
# Epoch 185/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8366e-04
# Epoch 186/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0168e-04
# Epoch 187/300
# 39/39 [==============================] - 0s 7ms/step - loss: 6.5944e-04
# Epoch 188/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7256e-04
# Epoch 189/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9617e-04
# Epoch 190/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6259e-04
# Epoch 191/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0582e-04
# Epoch 192/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8390e-04
# Epoch 193/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5157e-04
# Epoch 194/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5935e-04
# Epoch 195/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7516e-04
# Epoch 196/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5158e-04
# Epoch 197/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8662e-04
# Epoch 198/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5095e-04
# Epoch 199/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4781e-04
# Epoch 200/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6392e-04
# Epoch 201/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8430e-04
# Epoch 202/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8482e-04
# Epoch 203/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7903e-04
# Epoch 204/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4753e-04
# Epoch 205/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7604e-04
# Epoch 206/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5937e-04
# Epoch 207/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5407e-04
# Epoch 208/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5973e-04
# Epoch 209/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5637e-04
# Epoch 210/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4331e-04
# Epoch 211/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6141e-04
# Epoch 212/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.4575e-04
# Epoch 213/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9058e-04
# Epoch 214/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9207e-04
# Epoch 215/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8645e-04
# Epoch 216/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7629e-04
# Epoch 217/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4760e-04
# Epoch 218/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5129e-04
# Epoch 219/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5109e-04
# Epoch 220/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6763e-04
# Epoch 221/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5254e-04
# Epoch 222/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7316e-04
# Epoch 223/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5920e-04
# Epoch 224/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8558e-04
# Epoch 225/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6166e-04
# Epoch 226/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4796e-04
# Epoch 227/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6842e-04
# Epoch 228/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4963e-04
# Epoch 229/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8456e-04
# Epoch 230/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6080e-04
# Epoch 231/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8080e-04
# Epoch 232/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6313e-04
# Epoch 233/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.5043e-04
# Epoch 234/300
# 39/39 [==============================] - 0s 12ms/step - loss: 6.0734e-04
# Epoch 235/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9833e-04
# Epoch 236/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7067e-04
# Epoch 237/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.3776e-04
# Epoch 238/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7725e-04
# Epoch 239/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5223e-04
# Epoch 240/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.6210e-04
# Epoch 241/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1705e-04
# Epoch 242/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7237e-04
# Epoch 243/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8342e-04
# Epoch 244/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.4792e-04
# Epoch 245/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5020e-04
# Epoch 246/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5723e-04
# Epoch 247/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7053e-04
# Epoch 248/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7555e-04
# Epoch 249/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7477e-04
# Epoch 250/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4313e-04
# Epoch 251/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9520e-04
# Epoch 252/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5251e-04
# Epoch 253/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7848e-04
# Epoch 254/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5731e-04
# Epoch 255/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.4044e-04
# Epoch 256/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4819e-04
# Epoch 257/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4259e-04
# Epoch 258/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5030e-04
# Epoch 259/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4101e-04
# Epoch 260/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5216e-04
# Epoch 261/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6851e-04
# Epoch 262/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9002e-04
# Epoch 263/300
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0321e-04
# Epoch 264/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8721e-04
# Epoch 265/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6033e-04
# Epoch 266/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5105e-04
# Epoch 267/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5432e-04
# Epoch 268/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7595e-04
# Epoch 269/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8274e-04
# Epoch 270/300
# 39/39 [==============================] - 0s 7ms/step - loss: 5.4977e-04
# Epoch 271/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7670e-04
# Epoch 272/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5290e-04
# Epoch 273/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4969e-04
# Epoch 274/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6168e-04
# Epoch 275/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4436e-04
# Epoch 276/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7185e-04
# Epoch 277/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4266e-04
# Epoch 278/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5214e-04
# Epoch 279/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5354e-04
# Epoch 280/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6624e-04
# Epoch 281/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7975e-04
# Epoch 282/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.3953e-04
# Epoch 283/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4373e-04
# Epoch 284/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4367e-04
# Epoch 285/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5716e-04
# Epoch 286/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5252e-04
# Epoch 287/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9726e-04
# Epoch 288/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5283e-04
# Epoch 289/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5463e-04
# Epoch 290/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.3634e-04
# Epoch 291/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4455e-04
# Epoch 292/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6944e-04
# Epoch 293/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5799e-04
# Epoch 294/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4760e-04
# Epoch 295/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.4905e-04
# Epoch 296/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6781e-04
# Epoch 297/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6977e-04
# Epoch 298/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.3736e-04
# Epoch 299/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7077e-04
# Epoch 300/300
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5423e-04
# Epoch 1/100
# 39/39 [==============================] - 2s 7ms/step - loss: 0.0097
# Epoch 2/100
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 3/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 4/100
# 39/39 [==============================] - 0s 7ms/step - loss: 9.9104e-04
# Epoch 5/100
# 39/39 [==============================] - 0s 7ms/step - loss: 9.6082e-04
# Epoch 6/100
# 39/39 [==============================] - 0s 8ms/step - loss: 8.6671e-04
# Epoch 7/100
# 39/39 [==============================] - 0s 7ms/step - loss: 8.4243e-04
# Epoch 8/100
# 39/39 [==============================] - 0s 8ms/step - loss: 8.3789e-04
# Epoch 9/100
# 39/39 [==============================] - 0s 7ms/step - loss: 8.2793e-04
# Epoch 10/100
# 39/39 [==============================] - 0s 10ms/step - loss: 8.4286e-04
# Epoch 11/100
# 39/39 [==============================] - 0s 11ms/step - loss: 8.1790e-04
# Epoch 12/100
# 39/39 [==============================] - 0s 10ms/step - loss: 7.6108e-04
# Epoch 13/100
# 39/39 [==============================] - 0s 11ms/step - loss: 8.0631e-04
# Epoch 14/100
# 39/39 [==============================] - 0s 11ms/step - loss: 8.9109e-04
# Epoch 15/100
# 39/39 [==============================] - 0s 10ms/step - loss: 6.8057e-04
# Epoch 16/100
# 39/39 [==============================] - 0s 11ms/step - loss: 7.0776e-04
# Epoch 17/100
# 39/39 [==============================] - 0s 9ms/step - loss: 7.0799e-04
# Epoch 18/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.7440e-04
# Epoch 19/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.4577e-04
# Epoch 20/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.9526e-04
# Epoch 21/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.6503e-04
# Epoch 22/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.7439e-04
# Epoch 23/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.8236e-04
# Epoch 24/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.2400e-04
# Epoch 25/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.5017e-04
# Epoch 26/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.1158e-04
# Epoch 27/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.2767e-04
# Epoch 28/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.1056e-04
# Epoch 29/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.4679e-04
# Epoch 30/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.3014e-04
# Epoch 31/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.4066e-04
# Epoch 32/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.0624e-04
# Epoch 33/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9361e-04
# Epoch 34/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.9174e-04
# Epoch 35/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.9977e-04
# Epoch 36/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0700e-04
# Epoch 37/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.2434e-04
# Epoch 38/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.2070e-04
# Epoch 39/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8122e-04
# Epoch 40/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.0783e-04
# Epoch 41/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8046e-04
# Epoch 42/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.2175e-04
# Epoch 43/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6636e-04
# Epoch 44/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7942e-04
# Epoch 45/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7163e-04
# Epoch 46/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8405e-04
# Epoch 47/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.0357e-04
# Epoch 48/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8982e-04
# Epoch 49/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8075e-04
# Epoch 50/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6345e-04
# Epoch 51/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.9005e-04
# Epoch 52/100
# 39/39 [==============================] - 0s 11ms/step - loss: 6.2573e-04
# Epoch 53/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.9616e-04
# Epoch 54/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8001e-04
# Epoch 55/100
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7782e-04
# Epoch 56/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5791e-04
# Epoch 57/100
# 39/39 [==============================] - 0s 12ms/step - loss: 5.7035e-04
# Epoch 58/100
# 39/39 [==============================] - 0s 13ms/step - loss: 5.7705e-04
# Epoch 59/100
# 39/39 [==============================] - 0s 12ms/step - loss: 5.5283e-04
# Epoch 60/100
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7545e-04
# Epoch 61/100
# 39/39 [==============================] - 0s 10ms/step - loss: 6.4023e-04
# Epoch 62/100
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1033e-04
# Epoch 63/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.9573e-04
# Epoch 64/100
# 39/39 [==============================] - 0s 10ms/step - loss: 6.2132e-04
# Epoch 65/100
# 39/39 [==============================] - 0s 9ms/step - loss: 6.1703e-04
# Epoch 66/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6147e-04
# Epoch 67/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7246e-04
# Epoch 68/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8632e-04
# Epoch 69/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.8722e-04
# Epoch 70/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7776e-04
# Epoch 71/100
# 39/39 [==============================] - 0s 8ms/step - loss: 6.1030e-04
# Epoch 72/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7256e-04
# Epoch 73/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.6627e-04
# Epoch 74/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5839e-04
# Epoch 75/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7257e-04
# Epoch 76/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5696e-04
# Epoch 77/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.6868e-04
# Epoch 78/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5381e-04
# Epoch 79/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5747e-04
# Epoch 80/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.0399e-04
# Epoch 81/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7607e-04
# Epoch 82/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7056e-04
# Epoch 83/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5529e-04
# Epoch 84/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.5720e-04
# Epoch 85/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.8325e-04
# Epoch 86/100
# 39/39 [==============================] - 0s 7ms/step - loss: 5.7992e-04
# Epoch 87/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7141e-04
# Epoch 88/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7547e-04
# Epoch 89/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7436e-04
# Epoch 90/100
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1771e-04
# Epoch 91/100
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7007e-04
# Epoch 92/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5569e-04
# Epoch 93/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6822e-04
# Epoch 94/100
# 39/39 [==============================] - 0s 10ms/step - loss: 6.7905e-04
# Epoch 95/100
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9738e-04
# Epoch 96/100
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6990e-04
# Epoch 97/100
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5131e-04
# Epoch 98/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.7262e-04
# Epoch 99/100
# 39/39 [==============================] - 0s 8ms/step - loss: 5.5847e-04
# Epoch 100/100
# 39/39 [==============================] - 0s 7ms/step - loss: 6.1053e-04
# Epoch 1/300
# 39/39 [==============================] - 6s 10ms/step - loss: 0.0163
# Epoch 2/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0029
# Epoch 3/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0024
# Epoch 4/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0024
# Epoch 5/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 6/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 7/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 8/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 9/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 10/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 11/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 12/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 13/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 14/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 15/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 16/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 17/300
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 18/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 19/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 20/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 21/300
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 22/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 23/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 24/300
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 25/300
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0011
# Epoch 26/300
# 39/39 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 27/300
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0011
# Epoch 28/300
# 39/39 [==============================] - 1s 17ms/step - loss: 9.6240e-04
# Epoch 29/300
# 39/39 [==============================] - 0s 11ms/step - loss: 9.6502e-04
# Epoch 30/300
# 39/39 [==============================] - 0s 11ms/step - loss: 9.2643e-04
# Epoch 31/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.5689e-04
# Epoch 32/300
# 39/39 [==============================] - 0s 10ms/step - loss: 9.6162e-04
# Epoch 33/300
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 34/300
# 39/39 [==============================] - 0s 10ms/step - loss: 9.4215e-04
# Epoch 35/300
# 39/39 [==============================] - 0s 11ms/step - loss: 8.6340e-04
# Epoch 36/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.9444e-04
# Epoch 37/300
# 39/39 [==============================] - 0s 10ms/step - loss: 9.3254e-04
# Epoch 38/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.8320e-04
# Epoch 39/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.5040e-04
# Epoch 40/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.9411e-04
# Epoch 41/300
# 39/39 [==============================] - 0s 10ms/step - loss: 9.8968e-04
# Epoch 42/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.9230e-04
# Epoch 43/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.7630e-04
# Epoch 44/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.3670e-04
# Epoch 45/300
# 39/39 [==============================] - 0s 11ms/step - loss: 8.0072e-04
# Epoch 46/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.7288e-04
# Epoch 47/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.4257e-04
# Epoch 48/300
# 39/39 [==============================] - 0s 11ms/step - loss: 8.1651e-04
# Epoch 49/300
# 39/39 [==============================] - 0s 11ms/step - loss: 8.2027e-04
# Epoch 50/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.3517e-04
# Epoch 51/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.7562e-04
# Epoch 52/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.3443e-04
# Epoch 53/300
# 39/39 [==============================] - 0s 11ms/step - loss: 7.4150e-04
# Epoch 54/300
# 39/39 [==============================] - 1s 17ms/step - loss: 8.9133e-04
# Epoch 55/300
# 39/39 [==============================] - 1s 16ms/step - loss: 7.4037e-04
# Epoch 56/300
# 39/39 [==============================] - 1s 17ms/step - loss: 7.1595e-04
# Epoch 57/300
# 39/39 [==============================] - 1s 17ms/step - loss: 7.0065e-04
# Epoch 58/300
# 39/39 [==============================] - 1s 15ms/step - loss: 7.4502e-04
# Epoch 59/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.1093e-04
# Epoch 60/300
# 39/39 [==============================] - 0s 11ms/step - loss: 7.8837e-04
# Epoch 61/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.1667e-04
# Epoch 62/300
# 39/39 [==============================] - 0s 10ms/step - loss: 8.1261e-04
# Epoch 63/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.0867e-04
# Epoch 64/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.6415e-04
# Epoch 65/300
# 39/39 [==============================] - 0s 11ms/step - loss: 7.3492e-04
# Epoch 66/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.7471e-04
# Epoch 67/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.8223e-04
# Epoch 68/300
# 39/39 [==============================] - 0s 11ms/step - loss: 7.2748e-04
# Epoch 69/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.5703e-04
# Epoch 70/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.8208e-04
# Epoch 71/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.7976e-04
# Epoch 72/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.3987e-04
# Epoch 73/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1560e-04
# Epoch 74/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.1561e-04
# Epoch 75/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.5794e-04
# Epoch 76/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.4723e-04
# Epoch 77/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.3692e-04
# Epoch 78/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.7671e-04
# Epoch 79/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.3703e-04
# Epoch 80/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.6117e-04
# Epoch 81/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.3183e-04
# Epoch 82/300
# 39/39 [==============================] - 1s 13ms/step - loss: 6.3988e-04
# Epoch 83/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.1288e-04
# Epoch 84/300
# 39/39 [==============================] - 1s 17ms/step - loss: 7.5041e-04
# Epoch 85/300
# 39/39 [==============================] - 1s 17ms/step - loss: 7.4985e-04
# Epoch 86/300
# 39/39 [==============================] - 1s 17ms/step - loss: 6.3068e-04
# Epoch 87/300
# 39/39 [==============================] - 1s 15ms/step - loss: 6.5998e-04
# Epoch 88/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1477e-04
# Epoch 89/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9603e-04
# Epoch 90/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.3556e-04
# Epoch 91/300
# 39/39 [==============================] - 0s 10ms/step - loss: 7.1505e-04
# Epoch 92/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9569e-04
# Epoch 93/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.4467e-04
# Epoch 94/300
# 39/39 [==============================] - 0s 11ms/step - loss: 7.0364e-04
# Epoch 95/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8169e-04
# Epoch 96/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7181e-04
# Epoch 97/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.0506e-04
# Epoch 98/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.2867e-04
# Epoch 99/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9548e-04
# Epoch 100/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8674e-04
# Epoch 101/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8736e-04
# Epoch 102/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0307e-04
# Epoch 103/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.5803e-04
# Epoch 104/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7006e-04
# Epoch 105/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1359e-04
# Epoch 106/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0688e-04
# Epoch 107/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.3816e-04
# Epoch 108/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.3878e-04
# Epoch 109/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9669e-04
# Epoch 110/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.1678e-04
# Epoch 111/300
# 39/39 [==============================] - 1s 14ms/step - loss: 5.8480e-04
# Epoch 112/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.3056e-04
# Epoch 113/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.8178e-04
# Epoch 114/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.7275e-04
# Epoch 115/300
# 39/39 [==============================] - 1s 17ms/step - loss: 6.1353e-04
# Epoch 116/300
# 39/39 [==============================] - 1s 15ms/step - loss: 5.6918e-04
# Epoch 117/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5605e-04
# Epoch 118/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9290e-04
# Epoch 119/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8348e-04
# Epoch 120/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7300e-04
# Epoch 121/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8989e-04
# Epoch 122/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.4130e-04
# Epoch 123/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8193e-04
# Epoch 124/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8651e-04
# Epoch 125/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8192e-04
# Epoch 126/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8760e-04
# Epoch 127/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6583e-04
# Epoch 128/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7248e-04
# Epoch 129/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6722e-04
# Epoch 130/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.4285e-04
# Epoch 131/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6403e-04
# Epoch 132/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7603e-04
# Epoch 133/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.1902e-04
# Epoch 134/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5930e-04
# Epoch 135/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7720e-04
# Epoch 136/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7948e-04
# Epoch 137/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6909e-04
# Epoch 138/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.0537e-04
# Epoch 139/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.6713e-04
# Epoch 140/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.7307e-04
# Epoch 141/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.2727e-04
# Epoch 142/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.0873e-04
# Epoch 143/300
# 39/39 [==============================] - 1s 16ms/step - loss: 5.7137e-04
# Epoch 144/300
# 39/39 [==============================] - 1s 18ms/step - loss: 6.3547e-04
# Epoch 145/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5376e-04
# Epoch 146/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5727e-04
# Epoch 147/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7864e-04
# Epoch 148/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6701e-04
# Epoch 149/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8973e-04
# Epoch 150/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4938e-04
# Epoch 151/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5792e-04
# Epoch 152/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5623e-04
# Epoch 153/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7557e-04
# Epoch 154/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8651e-04
# Epoch 155/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9759e-04
# Epoch 156/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8312e-04
# Epoch 157/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6190e-04
# Epoch 158/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7251e-04
# Epoch 159/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8149e-04
# Epoch 160/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8522e-04
# Epoch 161/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6154e-04
# Epoch 162/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7170e-04
# Epoch 163/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.3698e-04
# Epoch 164/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.5835e-04
# Epoch 165/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7766e-04
# Epoch 166/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7146e-04
# Epoch 167/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9494e-04
# Epoch 168/300
# 39/39 [==============================] - 1s 15ms/step - loss: 5.6734e-04
# Epoch 169/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.0559e-04
# Epoch 170/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.8350e-04
# Epoch 171/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.7700e-04
# Epoch 172/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.0264e-04
# Epoch 173/300
# 39/39 [==============================] - 1s 14ms/step - loss: 5.7468e-04
# Epoch 174/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.1656e-04
# Epoch 175/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7008e-04
# Epoch 176/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.3251e-04
# Epoch 177/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.0724e-04
# Epoch 178/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.3333e-04
# Epoch 179/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6253e-04
# Epoch 180/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5176e-04
# Epoch 181/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.4156e-04
# Epoch 182/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.9695e-04
# Epoch 183/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7636e-04
# Epoch 184/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7273e-04
# Epoch 185/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9526e-04
# Epoch 186/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5858e-04
# Epoch 187/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6460e-04
# Epoch 188/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5947e-04
# Epoch 189/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.3880e-04
# Epoch 190/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8037e-04
# Epoch 191/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.7506e-04
# Epoch 192/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8616e-04
# Epoch 193/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5957e-04
# Epoch 194/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6704e-04
# Epoch 195/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8555e-04
# Epoch 196/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6685e-04
# Epoch 197/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.4833e-04
# Epoch 198/300
# 39/39 [==============================] - 1s 18ms/step - loss: 6.1564e-04
# Epoch 199/300
# 39/39 [==============================] - 1s 16ms/step - loss: 5.8758e-04
# Epoch 200/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.5013e-04
# Epoch 201/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.9192e-04
# Epoch 202/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.9298e-04
# Epoch 203/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8858e-04
# Epoch 204/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6151e-04
# Epoch 205/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5011e-04
# Epoch 206/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7864e-04
# Epoch 207/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6376e-04
# Epoch 208/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8679e-04
# Epoch 209/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8772e-04
# Epoch 210/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6327e-04
# Epoch 211/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5955e-04
# Epoch 212/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5714e-04
# Epoch 213/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8201e-04
# Epoch 214/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4331e-04
# Epoch 215/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0789e-04
# Epoch 216/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8389e-04
# Epoch 217/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.7691e-04
# Epoch 218/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5806e-04
# Epoch 219/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6744e-04
# Epoch 220/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.8865e-04
# Epoch 221/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.6427e-04
# Epoch 222/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0317e-04
# Epoch 223/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7516e-04
# Epoch 224/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4602e-04
# Epoch 225/300
# 39/39 [==============================] - 0s 12ms/step - loss: 6.1156e-04
# Epoch 226/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.6955e-04
# Epoch 227/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.9229e-04
# Epoch 228/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.8961e-04
# Epoch 229/300
# 39/39 [==============================] - 1s 18ms/step - loss: 5.5508e-04
# Epoch 230/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.2869e-04
# Epoch 231/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6022e-04
# Epoch 232/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6508e-04
# Epoch 233/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8431e-04
# Epoch 234/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4928e-04
# Epoch 235/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4400e-04
# Epoch 236/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5692e-04
# Epoch 237/300
# 39/39 [==============================] - 0s 11ms/step - loss: 6.1536e-04
# Epoch 238/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5762e-04
# Epoch 239/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5268e-04
# Epoch 240/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6061e-04
# Epoch 241/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5763e-04
# Epoch 242/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4660e-04
# Epoch 243/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.4580e-04
# Epoch 244/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9157e-04
# Epoch 245/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5299e-04
# Epoch 246/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7736e-04
# Epoch 247/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.4993e-04
# Epoch 248/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.4930e-04
# Epoch 249/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5501e-04
# Epoch 250/300
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0302e-04
# Epoch 251/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8542e-04
# Epoch 252/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7923e-04
# Epoch 253/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6131e-04
# Epoch 254/300
# 39/39 [==============================] - 1s 15ms/step - loss: 5.6110e-04
# Epoch 255/300
# 39/39 [==============================] - 1s 16ms/step - loss: 6.2312e-04
# Epoch 256/300
# 39/39 [==============================] - 1s 16ms/step - loss: 5.5233e-04
# Epoch 257/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.5964e-04
# Epoch 258/300
# 39/39 [==============================] - 1s 18ms/step - loss: 5.5843e-04
# Epoch 259/300
# 39/39 [==============================] - 1s 16ms/step - loss: 5.5093e-04
# Epoch 260/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6502e-04
# Epoch 261/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8075e-04
# Epoch 262/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6868e-04
# Epoch 263/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6350e-04
# Epoch 264/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4231e-04
# Epoch 265/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9901e-04
# Epoch 266/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8804e-04
# Epoch 267/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8607e-04
# Epoch 268/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4258e-04
# Epoch 269/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6843e-04
# Epoch 270/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6862e-04
# Epoch 271/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.8942e-04
# Epoch 272/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6975e-04
# Epoch 273/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7004e-04
# Epoch 274/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6041e-04
# Epoch 275/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7617e-04
# Epoch 276/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9851e-04
# Epoch 277/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5238e-04
# Epoch 278/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.5343e-04
# Epoch 279/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.3612e-04
# Epoch 280/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4544e-04
# Epoch 281/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.3949e-04
# Epoch 282/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.4438e-04
# Epoch 283/300
# 39/39 [==============================] - 1s 18ms/step - loss: 5.7165e-04
# Epoch 284/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.3751e-04
# Epoch 285/300
# 39/39 [==============================] - 1s 16ms/step - loss: 5.6180e-04
# Epoch 286/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.5914e-04
# Epoch 287/300
# 39/39 [==============================] - 1s 17ms/step - loss: 5.6385e-04
# Epoch 288/300
# 39/39 [==============================] - 0s 12ms/step - loss: 5.4801e-04
# Epoch 289/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4438e-04
# Epoch 290/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7673e-04
# Epoch 291/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.9283e-04
# Epoch 292/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9714e-04
# Epoch 293/300
# 39/39 [==============================] - 0s 10ms/step - loss: 5.6471e-04
# Epoch 294/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7187e-04
# Epoch 295/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4787e-04
# Epoch 296/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.3434e-04
# Epoch 297/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4238e-04
# Epoch 298/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.7220e-04
# Epoch 299/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.6540e-04
# Epoch 300/300
# 39/39 [==============================] - 0s 11ms/step - loss: 5.4534e-04

# %%
# Plot the loss values over epochs
plt.figure(figsize=(12, 8))
plt.plot(lstm_history.history['loss'])
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(gru_history.history['loss'])
plt.title('GRU Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(bilstm_history.history['loss'])
plt.title('Bidirectional LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Make predictions
train_predict_lstm = lstm_model.predict(train_X)
test_predict_lstm = lstm_model.predict(test_X)

train_predict_gru = gru_model.predict(train_X)
test_predict_gru = gru_model.predict(test_X)

train_predict_bilstm = bilstm_model.predict(train_X)
test_predict_bilstm = bilstm_model.predict(test_X)
# Out:
# 20/20 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 1s 4ms/step
# 5/5 [==============================] - 0s 5ms/step
# 20/20 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 6ms/step

# %%
train_rmse_lstm = np.sqrt(np.mean(np.square(train_y - train_predict_lstm)))
test_rmse_lstm = np.sqrt(np.mean(np.square(test_y - test_predict_lstm)))

train_rmse_gru = np.sqrt(np.mean(np.square(train_y - train_predict_gru)))
test_rmse_gru = np.sqrt(np.mean(np.square(test_y - test_predict_gru)))

train_rmse_bilstm = np.sqrt(np.mean(np.square(train_y - train_predict_bilstm)))
test_rmse_bilstm = np.sqrt(np.mean(np.square(test_y - test_predict_bilstm)))

train_mse_lstm = np.mean(np.square(train_y - train_predict_lstm))
test_mse_lstm = np.mean(np.square(test_y - test_predict_lstm))

train_mse_gru = np.mean(np.square(train_y - train_predict_gru))
test_mse_gru = np.mean(np.square(test_y - test_predict_gru))

train_mse_bilstm = np.mean(np.square(train_y - train_predict_bilstm))
test_mse_bilstm = np.mean(np.square(test_y - test_predict_bilstm))

train_mae_lstm = np.mean(np.abs(train_y - train_predict_lstm))
test_mae_lstm = np.mean(np.abs(test_y - test_predict_lstm))

train_mae_gru = np.mean(np.abs(train_y - train_predict_gru))
test_mae_gru = np.mean(np.abs(test_y - test_predict_gru))

train_mae_bilstm = np.mean(np.abs(train_y - train_predict_bilstm))
test_mae_bilstm = np.mean(np.abs(test_y - test_predict_bilstm))

train_mape_lstm = np.mean(np.abs((train_y - train_predict_lstm) / train_y)) * 100
test_mape_lstm = np.mean(np.abs((test_y - test_predict_lstm) / test_y)) * 100

train_mape_gru = np.mean(np.abs((train_y - train_predict_gru) / train_y)) * 100
test_mape_gru = np.mean(np.abs((test_y - test_predict_gru) / test_y)) * 100

train_mape_bilstm = np.mean(np.abs((train_y - train_predict_bilstm) / train_y)) * 100
test_mape_bilstm = np.mean(np.abs((test_y - test_predict_bilstm) / test_y)) * 100
# Out:
# <ipython-input-132-43a5af3719f7>:28: RuntimeWarning: divide by zero encountered in true_divide
#   train_mape_lstm = np.mean(np.abs((train_y - train_predict_lstm) / train_y)) * 100
# <ipython-input-132-43a5af3719f7>:31: RuntimeWarning: divide by zero encountered in true_divide
#   train_mape_gru = np.mean(np.abs((train_y - train_predict_gru) / train_y)) * 100
# <ipython-input-132-43a5af3719f7>:34: RuntimeWarning: divide by zero encountered in true_divide
#   train_mape_bilstm = np.mean(np.abs((train_y - train_predict_bilstm) / train_y)) * 100

# %%
# Print evaluation metrics
print('LSTM Train RMSE: %.6f' % (train_rmse_lstm))
print('LSTM Test RMSE: %.6f' % (test_rmse_lstm))
print('LSTM Train MSE: %.6f' % (train_mse_lstm))
print('LSTM Test MSE: %.6f' % (test_mse_lstm))
print('LSTM Train MAE: %.6f' % (train_mae_lstm))
print('LSTM Test MAE: %.6f' % (test_mae_lstm))
print('LSTM Train MAPE: %.6f%%' % (train_mape_lstm))
print('LSTM Test MAPE: %.6f%%' % (test_mape_lstm))

print('GRU Train RMSE: %.6f' % (train_rmse_gru))
print('GRU Test RMSE: %.6f' % (test_rmse_gru))
print('GRU Train MSE: %.6f' % (train_mse_gru))
print('GRU Test MSE: %.6f' % (test_mse_gru))
print('GRU Train MAE: %.6f' % (train_mae_gru))
print('GRU Test MAE: %.6f' % (test_mae_gru))
print('GRU Train MAPE: %.6f%%' % (train_mape_gru))
print('GRU Test MAPE: %.6f%%' % (test_mape_gru))

print('Bidirectional LSTM Train RMSE: %.6f' % (train_rmse_bilstm))
print('Bidirectional LSTM Test RMSE: %.6f' % (test_rmse_bilstm))
print('Bidirectional LSTM Train MSE: %.6f' % (train_mse_bilstm))
print('Bidirectional LSTM Test MSE: %.6f' % (test_mse_bilstm))
print('Bidirectional LSTM Train MAE: %.6f' % (train_mae_bilstm))
print('Bidirectional LSTM Test MAE: %.6f' % (test_mae_bilstm))
print('Bidirectional LSTM Train MAPE: %.6f%%' % (train_mape_bilstm))
print('Bidirectional LSTM Test MAPE: %.6f%%' % (test_mape_bilstm))
# Out:
# LSTM Train RMSE: 0.260894
# LSTM Test RMSE: 0.211257
# LSTM Train MSE: 0.068066
# LSTM Test MSE: 0.044630
# LSTM Train MAE: 0.195800
# LSTM Test MAE: 0.171164
# LSTM Train MAPE: inf%
# LSTM Test MAPE: 68.708882%
# GRU Train RMSE: 0.260747
# GRU Test RMSE: 0.210669
# GRU Train MSE: 0.067989
# GRU Test MSE: 0.044382
# GRU Train MAE: 0.195881
# GRU Test MAE: 0.170810
# GRU Train MAPE: inf%
# GRU Test MAPE: 69.495239%
# Bidirectional LSTM Train RMSE: 0.262164
# Bidirectional LSTM Test RMSE: 0.212493
# Bidirectional LSTM Train MSE: 0.068730
# Bidirectional LSTM Test MSE: 0.045153
# Bidirectional LSTM Train MAE: 0.196932
# Bidirectional LSTM Test MAE: 0.172260
# Bidirectional LSTM Train MAPE: inf%
# Bidirectional LSTM Test MAPE: 70.128691%

# %%
plt.figure(figsize=(12, 6))
plt.plot(test_y, label='Actual (Test)', color='blue')
plt.plot(test_predict_lstm, label='LSTM (Test)', color='orange')
plt.plot(test_predict_gru, label='GRU (Test)', color='green')
plt.plot(test_predict_bilstm, label='Bidirectional LSTM (Test)', color='red')
plt.title('Actual vs Predicted Bitcoin Price Normalized - Test')
plt.xlabel('Time')
plt.ylabel('Normalized Bitcoin Price')
plt.legend()
plt.show()

# %%
# Denormalize the predictions
train_predict_lstm = scaler.inverse_transform(train_predict_lstm)
test_predict_lstm = scaler.inverse_transform(test_predict_lstm)

train_predict_gru = scaler.inverse_transform(train_predict_gru)
test_predict_gru = scaler.inverse_transform(test_predict_gru)

train_predict_bilstm = scaler.inverse_transform(train_predict_bilstm)
test_predict_bilstm = scaler.inverse_transform(test_predict_bilstm)

# Denormalize the actual values
train_actual = scaler.inverse_transform(train_y.reshape(-1, 1))
test_actual = scaler.inverse_transform(test_y.reshape(-1, 1))

# %%
# Calculate evaluation metrics
train_rmse_lstm = np.sqrt(np.mean(np.square(train_actual - train_predict_lstm)))
test_rmse_lstm = np.sqrt(np.mean(np.square(test_actual - test_predict_lstm)))

train_rmse_gru = np.sqrt(np.mean(np.square(train_actual - train_predict_gru)))
test_rmse_gru = np.sqrt(np.mean(np.square(test_actual - test_predict_gru)))

train_rmse_bilstm = np.sqrt(np.mean(np.square(train_actual - train_predict_bilstm)))
test_rmse_bilstm = np.sqrt(np.mean(np.square(test_actual - test_predict_bilstm)))

train_mse_lstm = np.mean(np.square(train_actual - train_predict_lstm))
test_mse_lstm = np.mean(np.square(test_actual - test_predict_lstm))

train_mse_gru = np.mean(np.square(train_actual - train_predict_gru))
test_mse_gru = np.mean(np.square(test_actual - test_predict_gru))

train_mse_bilstm = np.mean(np.square(train_actual - train_predict_bilstm))
test_mse_bilstm = np.mean(np.square(test_actual - test_predict_bilstm))

train_mae_lstm = np.mean(np.abs(train_actual - train_predict_lstm))
test_mae_lstm = np.mean(np.abs(test_actual - test_predict_lstm))

train_mae_gru = np.mean(np.abs(train_actual - train_predict_gru))
test_mae_gru = np.mean(np.abs(test_actual - test_predict_gru))

train_mae_bilstm = np.mean(np.abs(train_actual - train_predict_bilstm))
test_mae_bilstm = np.mean(np.abs(test_actual - test_predict_bilstm))

train_mape_lstm = np.mean(np.abs((train_actual - train_predict_lstm) / train_actual)) * 100
test_mape_lstm = np.mean(np.abs((test_actual - test_predict_lstm) / test_actual)) * 100

train_mape_gru = np.mean(np.abs((train_actual - train_predict_gru) / train_actual)) * 100
test_mape_gru = np.mean(np.abs((test_actual - test_predict_gru) / test_actual)) * 100

train_mape_bilstm = np.mean(np.abs((train_actual - train_predict_bilstm) / train_actual)) * 100
test_mape_bilstm = np.mean(np.abs((test_actual - test_predict_bilstm) / test_actual)) * 100

# %%
# Print evaluation metrics
print('LSTM Train RMSE: %.6f' % (train_rmse_lstm))
print('LSTM Test RMSE: %.6f' % (test_rmse_lstm))
print('LSTM Train MSE: %.6f' % (train_mse_lstm))
print('LSTM Test MSE: %.6f' % (test_mse_lstm))
print('LSTM Train MAE: %.6f' % (train_mae_lstm))
print('LSTM Test MAE: %.6f' % (test_mae_lstm))
print('LSTM Train MAPE: %.6f%%' % (train_mape_lstm))
print('LSTM Test MAPE: %.6f%%' % (test_mape_lstm))

print('GRU Train RMSE: %.6f' % (train_rmse_gru))
print('GRU Test RMSE: %.6f' % (test_rmse_gru))
print('GRU Train MSE: %.6f' % (train_mse_gru))
print('GRU Test MSE: %.6f' % (test_mse_gru))
print('GRU Train MAE: %.6f' % (train_mae_gru))
print('GRU Test MAE: %.6f' % (test_mae_gru))
print('GRU Train MAPE: %.6f%%' % (train_mape_gru))
print('GRU Test MAPE: %.6f%%' % (test_mape_gru))

print('Bidirectional LSTM Train RMSE: %.6f' % (train_rmse_bilstm))
print('Bidirectional LSTM Test RMSE: %.6f' % (test_rmse_bilstm))
print('Bidirectional LSTM Train MSE: %.6f' % (train_mse_bilstm))
print('Bidirectional LSTM Test MSE: %.6f' % (test_mse_bilstm))
print('Bidirectional LSTM Train MAE: %.6f' % (train_mae_bilstm))
print('Bidirectional LSTM Test MAE: %.6f' % (test_mae_bilstm))
print('Bidirectional LSTM Train MAPE: %.6f%%' % (train_mape_bilstm))
print('Bidirectional LSTM Test MAPE: %.6f%%' % (test_mape_bilstm))
# LSTM Train RMSE: 449.457226
# LSTM Test RMSE: 442.274723
# LSTM Train MSE: 202011.798077
# LSTM Test MSE: 195606.930574
# LSTM Train MAE: 290.248395
# LSTM Test MAE: 286.594886
# LSTM Train MAPE: 4.131553%
# LSTM Test MAPE: 3.443388%
# GRU Train RMSE: 411.422682
# GRU Test RMSE: 422.203588
# GRU Train MSE: 169268.622929
# GRU Test MSE: 178255.869503
# GRU Train MAE: 241.098019
# GRU Test MAE: 269.661025
# GRU Train MAPE: 3.334109%
# GRU Test MAPE: 3.084153%
# Bidirectional LSTM Train RMSE: 424.090929
# Bidirectional LSTM Test RMSE: 440.430839
# Bidirectional LSTM Train MSE: 179853.115727
# Bidirectional LSTM Test MSE: 193979.323850
# Bidirectional LSTM Train MAE: 256.621174
# Bidirectional LSTM Test MAE: 292.747768
# Bidirectional LSTM Train MAPE: 3.684123%
# Bidirectional LSTM Test MAPE: 3.566017%
# Out:
# LSTM Train RMSE: 405.763019
# LSTM Test RMSE: 430.916389
# LSTM Train MSE: 164643.627329
# LSTM Test MSE: 185688.933892
# LSTM Train MAE: 236.086004
# LSTM Test MAE: 277.401120
# LSTM Train MAPE: 3.213182%
# LSTM Test MAPE: 3.170895%
# GRU Train RMSE: 423.131264
# GRU Test RMSE: 432.212005
# GRU Train MSE: 179040.066760
# GRU Test MSE: 186807.216889
# GRU Train MAE: 272.606106
# GRU Test MAE: 285.464238
# GRU Train MAPE: 3.996074%
# GRU Test MAPE: 3.438873%
# Bidirectional LSTM Train RMSE: 423.723772
# Bidirectional LSTM Test RMSE: 443.293991
# Bidirectional LSTM Train MSE: 179541.835300
# Bidirectional LSTM Test MSE: 196509.562121
# Bidirectional LSTM Train MAE: 267.965823
# Bidirectional LSTM Test MAE: 280.103160
# Bidirectional LSTM Train MAPE: 3.840265%
# Bidirectional LSTM Test MAPE: 3.313521%

# %%
import matplotlib.pyplot as plt

# # Plot actual vs predicted Bitcoin price (normalized values)
# plt.figure(figsize=(12, 6))
# plt.plot(train_actual, label='Actual (Train)', color='blue')
# plt.plot(train_predict_lstm, label='LSTM (Train)', color='orange')
# plt.plot(train_predict_gru, label='GRU (Train)', color='green')
# plt.plot(train_predict_bilstm, label='Bidirectional LSTM (Train)', color='red')
# plt.title('Actual vs Predicted Bitcoin Price (Normalized) - Train')
# plt.xlabel('Time')
# plt.ylabel('Normalized Bitcoin Price')
# plt.legend()
# plt.show()

plt.figure(figsize=(12, 6))
plt.plot(test_actual, label='Actual (Test)')
plt.plot(test_predict_lstm, label='LSTM (Test)')
# plt.plot(test_predict_gru, label='GRU (Test)', color='green')
# plt.plot(test_predict_bilstm, label='Bidirectional LSTM (Test)', color='red', linestyle = 'dashed')
plt.title('Actual vs Predicted Bitcoin Price - Test')
plt.xlabel('Time')
plt.ylabel('Bitcoin Price (USD)')
plt.legend()
plt.show()

###################################################################################################
plt.figure(figsize=(12, 6))
plt.plot(test_actual, label='Actual (Test)')
# plt.plot(test_predict_lstm, label='LSTM (Test)', color='black')
plt.plot(test_predict_gru, label='GRU (Test)')
# plt.plot(test_predict_bilstm, label='Bidirectional LSTM (Test)', color='red', linestyle = 'dashed')
plt.title('Actual vs Predicted Bitcoin Price - Test')
plt.xlabel('Time')
plt.ylabel('Bitcoin Price (USD)')
plt.legend()
plt.show()

###################################################################################################
plt.figure(figsize=(12, 6))
plt.plot(test_actual, label='Actual (Test)')
# plt.plot(test_predict_lstm, label='LSTM (Test)', color='black')
# plt.plot(test_predict_gru, label='GRU (Test)')
plt.plot(test_predict_bilstm, label='Bidirectional LSTM (Test)')
plt.title('Actual vs Predicted Bitcoin Price - Test')
plt.xlabel('Time')
plt.ylabel('Bitcoin Price USD')
plt.legend()
plt.show()


###################################################################################################
plt.figure(figsize=(12, 6))
plt.plot(test_actual, label='Actual (Test)')
plt.plot(test_predict_lstm, label='LSTM (Test)')
plt.plot(test_predict_gru, label='GRU (Test)')
plt.plot(test_predict_bilstm, label='Bidirectional LSTM (Test)')
plt.title('Actual vs Predicted Bitcoin Price - Test')
plt.xlabel('Time')
plt.ylabel('Bitcoin Price (USD)')
plt.legend()
plt.show()

# # Plot actual vs predicted Bitcoin price (denormalized values)
# plt.figure(figsize=(12, 6))
# plt.plot(scaler.inverse_transform(train_actual), label='Actual (Train)', color='blue')
# plt.plot(train_predict_lstm, label='LSTM (Train)', color='orange')
# plt.plot(train_predict_gru, label='GRU (Train)', color='green')
# plt.plot(train_predict_bilstm, label='Bidirectional LSTM (Train)', color='red')
# plt.title('Actual vs Predicted Bitcoin Price (Denormalized) - Train')
# plt.xlabel('Time')
# plt.ylabel('Bitcoin Price')
# plt.legend()
# plt.show()

# plt.figure(figsize=(12, 6))
# plt.plot(scaler.inverse_transform(test_actual), label='Actual (Test)', color='blue')
# plt.plot(test_predict_lstm, label='LSTM (Test)', color='orange')
# plt.plot(test_predict_gru, label='GRU (Test)', color='green')
# plt.plot(test_predict_bilstm, label='Bidirectional LSTM (Test)', color='red')
# plt.title('Actual vs Predicted Bitcoin Price (Denormalized) - Test')
# plt.xlabel('Time')
# plt.ylabel('Bitcoin Price')
# plt.legend()
# plt.show()
