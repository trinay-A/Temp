# %% [markdown]
# <a href="https://colab.research.google.com/github/trinay-A/Temp/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime
warnings.filterwarnings('ignore')
plt.style.use('seaborn-poster')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf3b282b-f0c6-485c-9abe-0bca2e7b0155" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf3b282b-f0c6-485c-9abe-0bca2e7b0155">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('/content/DataBTC.csv',index_col= 'Time')

# %%
print(data.head(5)) 
data.info()
data.index = pd.to_datetime(data.index)
print(data.index)
data.head(5)
# Out:
#                   Price
# Time
# 2017-01-01   997.257358
# 2017-01-02  1017.077886
# 2017-01-03  1032.609053
# 2017-01-04  1134.496445
# 2017-01-05  1000.498129
# <class 'pandas.core.frame.DataFrame'>
# Index: 2191 entries, 2017-01-01 to 2022-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2191 non-null   float64
# dtypes: float64(1)
# memory usage: 34.2+ KB
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', name='Time', length=2191, freq=None)
#                   Price
# Time
# 2017-01-01   997.257358
# ...

# %%
data = data.sort_index()
data.head()
# Out:
#                   Price
# Time
# 2017-01-01   997.257358
# 2017-01-02  1017.077886
# 2017-01-03  1032.609053
# 2017-01-04  1134.496445
# 2017-01-05  1000.498129

# %%
data['Price'].plot(figsize=(30, 6))
plt.ylabel("Daily Bitcoin price")

weekly = data.resample('W').mean()
weekly.plot(figsize=(30, 6))
plt.ylabel('Weekly bitcoin price')

df_month = data.resample('M').mean()
df_month.plot(figsize=(30, 6))
plt.ylabel('Monthly bitcoin price')
# Out:
# Text(0, 0.5, 'Monthly bitcoin price')

# %%
plt.figure(figsize=[15,7])
sm.tsa.seasonal_decompose(df_month.Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.458968

# %%
df_month['Weighted_Price_box'], lmbda = stats.boxcox(df_month.Price)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Price)[1])
# Out:
# Dickey–Fuller test: p=0.458968

# %%
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.228246

# %%
# Regular differentiation
df_month['prices_box_diff2'] = df_month.prices_box_diff - df_month.prices_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(df_month.prices_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.000429

# %%
# Initial approximation of parameters using Autocorrelation and Partial Autocorrelation Plots
plt.figure(figsize=(15,7))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df_month.prices_box_diff2[13:].values.squeeze(), lags=28, ax=ax)
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df_month.prices_box_diff2[13:].values.squeeze(), lags=28, ax=ax)
plt.tight_layout()
plt.show()

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
#       parameters         aic
# 19  (1, 0, 0, 1)  114.344727
# 22  (1, 0, 2, 0)  114.868708
# 23  (1, 0, 2, 1)  115.452622
# 7   (0, 1, 0, 1)  115.965727
# 37  (2, 0, 0, 1)  116.091933
#                                       SARIMAX Results
# ...
# Dep. Variable:                   Weighted_Price_box   No. Observations:                   72
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                 -54.172
# Date:                              Sun, 02 Apr 2023   AIC                            114.345
# Time:                                      18:03:22   BIC                            120.577
# Sample:                                  01-31-2017   HQIC                           116.778
#                                        - 12-31-2022
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# STL-decomposition
plt.figure(figsize=(15,7))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Dickey–Fuller test:: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])

plt.tight_layout()
plt.show()
# Out:
# Dickey–Fuller test:: p=0.000000

# %%
# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
# Prediction
df_month2 = df_month[['Price']]
date_list = [datetime(2017, 6, 30), datetime(2017, 7, 31), datetime(2017, 8, 31), datetime(2017, 9, 30), 
             datetime(2017, 10, 31), datetime(2017, 11, 30), datetime(2017, 12, 31), datetime(2018, 1, 31),
             datetime(2018, 1, 28)]
future = pd.DataFrame(index=date_list, columns= df_month.columns)
df_month2 = pd.concat([df_month2, future])
df_month2['forecast'] = invboxcox(best_model.predict(start=0, end=75), lmbda)
plt.figure(figsize=(15,7))
df_month2.Price.plot()
df_month2.forecast.plot(color='r', ls='--', label='Predicted Price')
plt.legend()
plt.title('Bitcoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()
